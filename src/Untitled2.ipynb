# %%
import pandas as pd

# %%
df = pd.read_csv("./sample.csv")
#tmp = df[df.car_name.str.contains('aizu_BL-01')]
#tmp = df['aizu_BL-01'.contains(df.car_name.str)]
        
print(dir(df.car_name.str))
str = "aizu_BL-01_10"
df.query('car_name=="'+str+'"')
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__frozen', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_data', '_freeze', '_is_categorical', '_orig', '_wrap_result', 'capitalize', 'cat', 'center', 'contains', 'count', 'decode', 'encode', 'endswith', 'extract', 'extractall', 'find', 'findall', 'get', 'get_dummies', 'index', 'isalnum', 'isalpha', 'isdecimal', 'isdigit', 'islower', 'isnumeric', 'isspace', 'istitle', 'isupper', 'join', 'len', 'ljust', 'lower', 'lstrip', 'match', 'normalize', 'pad', 'partition', 'repeat', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'slice', 'slice_replace', 'split', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'wrap', 'zfill']
# ...

# %%
car_df = df[df.car_name.str.contains('aizu_BL-01_10')]
car_df
# Out:
#               car_name measurement_data_id measurement_datetime  \
# 0        aizu_BL-01_10     20170220_083218  2017/02/20 08:32:18
# 1        aizu_BL-01_10     20170220_083218  2017/02/20 08:32:18
# 2        aizu_BL-01_10     20170220_083218  2017/02/20 08:32:18
# 3        aizu_BL-01_10     20170220_083218  2017/02/20 08:32:18
# 4        aizu_BL-01_10     20170220_083218  2017/02/20 08:32:18
# 5        aizu_BL-01_10     20170220_083218  2017/02/20 08:32:18
# 6        aizu_BL-01_10     20170220_083218  2017/02/20 08:32:18
# 7        aizu_BL-01_10     20170220_083218  2017/02/20 08:32:18
# 8        aizu_BL-01_10     20170220_083218  2017/02/20 08:32:18
# 9        aizu_BL-01_10     20170220_083218  2017/02/20 08:32:18
# 10       aizu_BL-01_10     20170220_083218  2017/02/20 08:32:18
# 11       aizu_BL-01_10     20170220_083218  2017/02/20 08:32:18
# 12       aizu_BL-01_10     20170220_083218  2017/02/20 08:32:18
# 13       aizu_BL-01_10     20170220_083218  2017/02/20 08:32:18
# ...
